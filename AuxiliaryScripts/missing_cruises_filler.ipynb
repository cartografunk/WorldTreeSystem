# %%
from core.db import get_engine
from sqlalchemy import text

contract_codes = ['GT0037', 'US0094', 'US0116', 'US0117']
inventory_year = 2025

engine = get_engine()
default_values = {
    "inventory_year": inventory_year,
    "inventory_date": "pending",
    "rel_path": "",
}

for code in contract_codes:
    pkid = f"{code} {inventory_year}"  # o usa '_' si prefieres: f"{code}_{inventory_year}"
    q = text("""
        INSERT INTO masterdatabase.inventory_metrics
            (contract_code, inventory_year, inventory_date, rel_path, pkid)
        VALUES
            (:contract_code, :inventory_year, :inventory_date, :rel_path, :pkid)
        ON CONFLICT (pkid) DO NOTHING
    """)
    with engine.begin() as conn:
        conn.execute(q, {
            "contract_code": code,
            "pkid": pkid,
            **default_values
        })
    print(f"✅ Insertado {code} para el año {inventory_year}")
# Out:
# 💻 Conectado a la base de datos helloworldtree
# ✅ Insertado GT0037 para el año 2025
# ✅ Insertado US0094 para el año 2025
# ✅ Insertado US0116 para el año 2025
# ✅ Insertado US0117 para el año 2025

# %%
from core.db import get_engine
from sqlalchemy import text

contract_codes = ['GT0037', 'US0094', 'US0116', 'US0117']
inventory_year = 2024

engine = get_engine()
default_values = {
    "inventory_year": inventory_year,
    "inventory_date": "pending",
    "rel_path": "",
}

for code in contract_codes:
    pkid = f"{code} {inventory_year}"  # o usa '_' si prefieres: f"{code}_{inventory_year}"
    q = text("""
        INSERT INTO masterdatabase.inventory_metrics
            (contract_code, inventory_year, inventory_date, rel_path, pkid)
        VALUES
            (:contract_code, :inventory_year, :inventory_date, :rel_path, :pkid)
        ON CONFLICT (pkid) DO NOTHING
    """)
    with engine.begin() as conn:
        conn.execute(q, {
            "contract_code": code,
            "pkid": pkid,
            **default_values
        })
    print(f"✅ Insertado {code} para el año {inventory_year}")

# %%
import json
from core.db import get_engine
from sqlalchemy import text
import pandas as pd

# --- Configura el batch y año que quieres checar ---
BATCH_PATH = r"C:\Users\HeyCe\World Tree Technologies Inc\Operations - Documentos\WorldTreeSystem\Cruises\batch_imports.json"
AÑO = 2024

# 1. Carga todos los contract_codes + rel_paths de batch_imports.json
with open(BATCH_PATH, encoding="utf-8") as f:
    lotes = json.load(f)

# Ajusta a tu estructura: aquí asumo que cada lote tiene archivos de un solo país/año
# Si tienes varios, filtra solo el lote que quieres
todos = []
for lote in lotes:
    if str(lote.get("año")) == str(AÑO):
        archivos = lote["archivos"]
        for a in archivos:
            # Asume formato: .../GT0037_algo.xlsx
            name = a.split('/')[-1].split('\\')[-1]
            contract_code = name.split('_')[0]
            todos.append({"contract_code": contract_code, "rel_path": a})
# Si hay duplicados, deja solo uno por contract_code:
batch_df = pd.DataFrame(todos).drop_duplicates("contract_code")

# 2. Consulta los contract_codes ya existentes en inventory_metrics para ese año
engine = get_engine()
sql = """
SELECT contract_code
FROM masterdatabase.inventory_metrics
WHERE inventory_year = :año
"""
existentes = pd.read_sql(text(sql), engine, params={"año": AÑO})

# 3. Diferencial: los que están en batch pero no en la tabla
faltantes = batch_df[~batch_df['contract_code'].isin(existentes['contract_code'])]

print(f"Total en batch: {len(batch_df)}")
print(f"Ya existen en DB: {len(existentes)}")
print(f"Faltan por insertar: {len(faltantes)}")
print(faltantes)

# 4. Inserta los faltantes con rel_path correcto
for _, row in faltantes.iterrows():
    code = row["contract_code"]
    rel_path = row["rel_path"]
    pkid = f"{code} {AÑO}"  # Si usas pkid, ajústalo aquí

    q = text("""
        INSERT INTO masterdatabase.inventory_metrics
            (contract_code, inventory_year, inventory_date, rel_path, pkid)
        VALUES
            (:contract_code, :inventory_year, :inventory_date, :rel_path, :pkid)
        ON CONFLICT (pkid) DO NOTHING
    """)
    with engine.begin() as conn:
        conn.execute(q, {
            "contract_code": code,
            "inventory_year": AÑO,
            "inventory_date": "pending",
            "rel_path": rel_path,
            "pkid": pkid
        })
    print(f"✅ Insertado {code} ({rel_path}) para {AÑO}")
# Out:
# 💻 Conectado a la base de datos helloworldtree
# Total en batch: 107
# Ya existen en DB: 68
# Faltan por insertar: 72
#        contract_code                                           rel_path
# 0             MX0021  Mexico/2023_ForestInventory/3-WT Cruises/Alvar...
# 2             MX0027  Mexico/2023_ForestInventory/3-WT Cruises/Carlo...
# 3             MX0028  Mexico/2023_ForestInventory/3-WT Cruises/Ciril...
# 5             MX0022  Mexico/2023_ForestInventory/3-WT Cruises/Grego...
# 6             MX0030  Mexico/2023_ForestInventory/3-WT Cruises/Herad...
# ..               ...                                                ...
# 102           CR0100  Costa Rica/2023_ForestInventory/3-WT Cruises/S...
# 103   Victor Godinez  Costa Rica/2023_ForestInventory/3-WT Cruises/V...
# 104   Wilbert Alfaro  Costa Rica/2023_ForestInventory/3-WT Cruises/W...
# 105   William Romero  Costa Rica/2023_ForestInventory/3-WT Cruises/W...
# 106  Wilman Alvarado  Costa Rica/2023_ForestInventory/3-WT Cruises/W...
#
# [72 rows x 2 columns]
# ✅ Insertado MX0021 (Mexico/2023_ForestInventory/3-WT Cruises/Alvaro Hernandez Suarez - MX0021/MX0021_2023_Alvaro Hernandez Suarez.xlsx) para 2024
# ✅ Insertado MX0027 (Mexico/2023_ForestInventory/3-WT Cruises/Carlos Carbajal - MX0027/MX0027_2023_Carlos Carbajal Gutierrez.xlsx) para 2024
# ✅ Insertado MX0028 (Mexico/2023_ForestInventory/3-WT Cruises/Cirilo Carbajal Hernandez - MX0028/MX0028_2023_Cirilo Carvajal Hernandez.xlsx) para 2024
# ✅ Insertado MX0022 (Mexico/2023_ForestInventory/3-WT Cruises/Gregorio Martinez Sebastian - MX0022/MX0022_2023_Gregorio Martinez Sebastian.xlsx) para 2024
# ✅ Insertado MX0030 (Mexico/2023_ForestInventory/3-WT Cruises/Heradio Hernandez Jimenez - MX0030/MX0030_Heradio Hernandez Jimenez.xlsx) para 2024
# ✅ Insertado MX0031 (Mexico/2023_ForestInventory/3-WT Cruises/Jesus Rauda Gutierrez - MX0031/MX0031_2023_Jesús Rauda Gutiérrez.xlsx) para 2024
# ✅ Insertado MX0033 (Mexico/2023_ForestInventory/3-WT Cruises/Lucas Raudas Guitierrez - MX0033/MX0033_2023_Lucas Rauda Gutiérrez.xlsx) para 2024
# ✅ Insertado MX0034 (Mexico/2023_ForestInventory/3-WT Cruises/Pedro Molina Sanchez - MX0034/MX0034_2023_Pedro Molina Sánchez.xlsx) para 2024
# ✅ Insertado MX0036 (Mexico/2023_ForestInventory/3-WT Cruises/Tito Soria - MX0036/MX0036_2023_Tito Soria Perez.xlsx) para 2024
# ✅ Insertado MX0037 (Mexico/2023_ForestInventory/3-WT Cruises/Ubaldo Guillermo Perez Cruz - MX0037/MX0037_2023_Ubaldo Guillermo Perez Cruz.xlsx) para 2024
# ✅ Insertado us0067 (USA/2023_ForestInventory/4-Contractor Cruises/Guy Goodson - US0067/us0067_us_2020_jcc.xlsx) para 2024
# ✅ Insertado us0068 (USA/2023_ForestInventory/4-Contractor Cruises/Jeff Barnes - US0068/us0068_us_2020_jcc.xlsx) para 2024
# ✅ Insertado us0070 (USA/2023_ForestInventory/4-Contractor Cruises/Jeff Rice - US0070/us0070_us_2020_jcc.xlsx) para 2024
# ✅ Insertado us0073 (USA/2023_ForestInventory/4-Contractor Cruises/Joseph Garrett - US0073/us0073_us_2020_jcc.xlsx) para 2024
# ✅ Insertado US0134 (USA/2023_ForestInventory/4-Contractor Cruises/Kennsel Bennett - US0134/US0134_US_2022_DallasEnfinger.xlsx) para 2024
# ✅ Insertado us0115 (USA/2023_ForestInventory/4-Contractor Cruises/Michael Roe - US0115/us0115_us_2021_jc.xlsx) para 2024
# ✅ Insertado us0078 (USA/2023_ForestInventory/4-Contractor Cruises/Pete Preskitt - US0078/us0078_us_2020_jcc.xlsx) para 2024
# ✅ Insertado us0081 (USA/2023_ForestInventory/4-Contractor Cruises/Ricky Mitchell - US0081/us0081_us_2020_jcc.xlsx) para 2024
# ✅ Insertado US0139 (USA/2023_ForestInventory/4-Contractor Cruises/Rob Cason - US0139/US0139_US_2022_DallasEnfinger.xlsx) para 2024
# ✅ Insertado us0083 (USA/2023_ForestInventory/4-Contractor Cruises/Russell and Sedalia Nelson - US0083/us0083_us_2020_jcc.xlsx) para 2024
# ✅ Insertado us0047 (USA/2023_ForestInventory/4-Contractor Cruises/Scott Willis - US0047/us0047_us_2019_jcc.xlsx) para 2024
# ✅ Insertado us0141 (USA/2023_ForestInventory/4-Contractor Cruises/Sisay Souphom - US0141/us0141_us_2022_jcc.xlsx) para 2024
# ✅ Insertado us0142 (USA/2023_ForestInventory/4-Contractor Cruises/Steven Hunter - US0142/us0142_us_2022_jcc.xlsx) para 2024
# ✅ Insertado us0143 (USA/2023_ForestInventory/4-Contractor Cruises/Todd McCarley - US0143/us0143_us_2022_jcc.xlsx) para 2024
# ✅ Insertado CR0037 - 2023 - Ana Wolfe Arce.xlsx (Costa Rica/2023_ForestInventory/3-WT Cruises/Ana Wolfe Arce - CR0037/CR0037 - 2023 - Ana Wolfe Arce.xlsx) para 2024
# ✅ Insertado CR0092 (Costa Rica/2023_ForestInventory/3-WT Cruises/Christian Araya - CR0092/CR0092_2023_Christian Araya.xlsx) para 2024
# ✅ Insertado CR0099 (Costa Rica/2023_ForestInventory/3-WT Cruises/Corporacion Comercial San Miguel del Pacifico S.A - CR0099/CR0099_2023_Corporacion Comercial San Miguel del Pacifico S.A.xlsx) para 2024
# ✅ Insertado Didier AlFaro (Costa Rica/2023_ForestInventory/3-WT Cruises/Didier Alfaro Alvarado - CR0042/Didier AlFaro_20038.xlsx) para 2024
# ✅ Insertado CR0104 (Costa Rica/2023_ForestInventory/3-WT Cruises/Emmanuel Manuel Ruiz - CR0104/CR0104_2023_Emmanuel Ruiz.xlsx) para 2024
# ✅ Insertado Elia Araya (Costa Rica/2023_ForestInventory/3-WT Cruises/Enrique Quiroz - CR0046/Elia Araya_CR0046.xlsx) para 2024
# ✅ Insertado Gregorio Corella (Costa Rica/2023_ForestInventory/3-WT Cruises/Gregorio Corella - CR0049/Gregorio Corella_CR0049.xlsx) para 2024
# ✅ Insertado Jeison Espinoza (Costa Rica/2023_ForestInventory/3-WT Cruises/Jeison Espinoza - CR0051/Jeison Espinoza_CR0051.xlsx) para 2024
# ✅ Insertado 20048-CR0052-I1.xlsx (Costa Rica/2023_ForestInventory/3-WT Cruises/Jerry Myers - CR0052/20048-CR0052-I1.xlsx) para 2024
# ✅ Insertado CR0105 (Costa Rica/2023_ForestInventory/3-WT Cruises/Johaner Rosales Flores - CR0105/CR0105_2023_Johaner Rosales.xlsx) para 2024
# ✅ Insertado CR0101-2023 (Costa Rica/2023_ForestInventory/3-WT Cruises/Jorge Alberto Cole - CR0103/CR0101-2023_Tecamachalco.xlsx) para 2024
# ✅ Insertado Eduardo Esquivel (Costa Rica/2023_ForestInventory/3-WT Cruises/Jose Eduardo Esquivel  - CR0053/Eduardo Esquivel_CR0053.xlsx) para 2024
# ✅ Insertado Marco Mora (Costa Rica/2023_ForestInventory/3-WT Cruises/Marco Mora (RFT)/Marco Mora_20054.xlsx) para 2024
# ✅ Insertado 20036-CR0040-I1.xlsx (Costa Rica/2023_ForestInventory/3-WT Cruises/Marco Pacheco - CR0040/20036-CR0040-I1.xlsx) para 2024
# ✅ Insertado Marianela Campos (Costa Rica/2023_ForestInventory/3-WT Cruises/Marianela Campos - CR0059/Marianela Campos_CR0059.xlsx) para 2024
# ✅ Insertado Mauricio Alvarado (Costa Rica/2023_ForestInventory/3-WT Cruises/Mauricio Alvarado - CR0039/Mauricio Alvarado_CR0039.xlsx) para 2024
# ✅ Insertado Mayela Quesada (Costa Rica/2023_ForestInventory/3-WT Cruises/Mayela Quesada - CR0061/Mayela Quesada_CR0061.xlsx) para 2024
# ✅ Insertado Mercedes Barboza (Costa Rica/2023_ForestInventory/3-WT Cruises/Mercedes Barboza - CR0062/Mercedes Barboza_CR0062.xlsx) para 2024
# ✅ Insertado Miguel Corrales (Costa Rica/2023_ForestInventory/3-WT Cruises/Miguel Corrales Venegas - CR0089/Miguel Corrales_CR0089.xlsx) para 2024
# ✅ Insertado Oldemar Perez (Costa Rica/2023_ForestInventory/3-WT Cruises/Oldemar Perez - CR0075/Oldemar Perez_20069.xlsx) para 2024
# ✅ Insertado Olga Chavarria (Costa Rica/2023_ForestInventory/3-WT Cruises/Olga Chavarria  - CR0076/Olga Chavarria_CR0076.xlsx) para 2024
# ✅ Insertado Olger Monge (Costa Rica/2023_ForestInventory/3-WT Cruises/Olger Monge - CR0063/Olger Monge_CR0063.xlsx) para 2024
# ✅ Insertado CR0100 (Costa Rica/2023_ForestInventory/3-WT Cruises/Samuel Wards - CR0100/CR0100_2023_Samuel Wards.xlsx) para 2024
# ✅ Insertado Victor Godinez (Costa Rica/2023_ForestInventory/3-WT Cruises/Victor Godinez - CR0066/Victor Godinez_20061.xlsx) para 2024
# ✅ Insertado Wilbert Alfaro (Costa Rica/2023_ForestInventory/3-WT Cruises/Wilberth Jesus Alfaro - CR0068/Wilbert Alfaro_20063.xlsx) para 2024
# ✅ Insertado William Romero (Costa Rica/2023_ForestInventory/3-WT Cruises/William Romero_CR0102/William Romero_CR0102.xlsx) para 2024
# ✅ Insertado Wilman Alvarado (Costa Rica/2023_ForestInventory/3-WT Cruises/Wilman Alvarado - CR0069/Wilman Alvarado_CR0069.xlsx) para 2024
